# %% [markdown]
# <a href="https://colab.research.google.com/github/jamesodukoya/WebScraping/blob/main/Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Scraping Table Data from Wikipedia

# %% [markdown]
# ##Importing Beautiful Soup Library

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue"

page = requests.get(url)

content = BeautifulSoup(page.text, 'html')

table=content.find_all('table')[1]

# %%
titles=table.find_all('th')
titles=[heading.text.strip() for heading in titles]

# %% [markdown]
# ##Importing Pandas and Creating Table

# %%
import pandas as pd
frame=pd.DataFrame(columns=titles)

# %% [markdown]
# ##Getting Data from Each Table Row and Adding It to Our Table

# %%
column_data=table.find_all('tr')

# %%
for row in column_data[1:]:
  row_data=row.find_all('td')
  individual_row_data=[data.text.strip() for data in row_data]
  length=len(frame)
  frame.loc[length]=individual_row_data
frame
# Out:
#    Rank                      Name                    Industry  \
# 0     1                   Walmart                      Retail
# 1     2                    Amazon  Retail and cloud computing
# 2     3                ExxonMobil          Petroleum industry
# 3     4                     Apple        Electronics industry
# 4     5        UnitedHealth Group                  Healthcare
# ..  ...                       ...                         ...
# 95   96                  Best Buy                      Retail
# 96   97      Bristol-Myers Squibb     Pharmaceutical industry
# 97   98           United Airlines                     Airline
# 98   99  Thermo Fisher Scientific      Laboratory instruments
# 99  100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %% [markdown]
# ##Exporting Table to Local CSV file

# %%
frame.to_csv(r'C:\Users\oduko\Downloads\Companies.csv', index=False)
